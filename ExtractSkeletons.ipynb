# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import kagglehub
import mediapipe as mp
import json
from IPython.display import HTML

import torch
from torch.utils.data import Dataset, DataLoader

# %%
path = kagglehub.dataset_download("soumicksarker/ipn-hand-dataset")
print(path)
# Out:
# /Users/steventan/.cache/kagglehub/datasets/soumicksarker/ipn-hand-dataset/versions/7

# %%
df = pd.read_csv(os.path.join(path, "metadata.csv"))
df.head()
# Out:
#         Video Name  Frames Sex   Hand Background Illumination People in Scene  \
# 0    1CM1_4_R__229    3751   W  Right    Clutter       Stable          Single
# 1    1CM1_4_R__230    3684   W  Right    Clutter       Stable          Single
# 2    1CM1_4_R__231    3747   W  Right    Clutter       Stable          Single
# 3    1CM1_4_R__232    3858   W  Right    Clutter       Stable          Single
# 4  1CM42_11_R__205    3686   M  Right      Plain       Stable          Single
#
#   Background Motion    Set  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0            Static  train         NaN          NaN          NaN          NaN
# 1            Static  train         NaN          NaN          NaN          NaN
# 2            Static  train         NaN          NaN          NaN          NaN
# 3            Static  train         NaN          NaN          NaN          NaN
# 4            Static  train         NaN          NaN          NaN          NaN
#
#    Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN

# %%
annotations_path = os.path.join(path, "annotations/annotations")
with open(os.path.join(annotations_path, "class_details.txt"), 'r') as f:
    for row in f:
        print(row)
# Out:
# id	Label	Gesture	Instances
#
# 1	D0X	Non-gesture
#
# 2	B0A	Pointing with one finger
#
# 3	B0B	Pointing with two fingers
#
# 4	G01	Click with one finger
#
# 5	G02	Click with two fingers
#
# 6	G03	Throw up
#
# 7	G04	Throw down
#
# 8	G05	Throw left
#
# 9	G06	Throw right
#
# 10	G07	Open twice
#
# 11	G08	Double click with one finger
#
# 12	G09	Double click with two fingers
#
# 13	G10	Zoom in
#
# 14	G11	Zoom out

# %%
def read_annotations(path):
    with open(path, 'r') as f:
        annots = []
        for idx, line in enumerate(f):
            if idx > 0:
                # Parse annotations and convert frame info into ints
                info = line.split(',')
                for i in range(2, len(info)):
                    info[i] = int(info[i])
                annots.append(info)
    return annots

# %%
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_styles = mp.solutions.drawing_styles

class IPNDataPreProcessor:
    def __init__(self, annots, dset_path, out_path):
        self.out_path = out_path
        self.dset_path = dset_path
        self.videos_path = os.path.join(dset_path, "videos/videos")
        
        self.annots = annots
        self.n = len(annots)
        
        self.hands = mp_hands.Hands(
            static_image_mode=False,
            max_num_hands=1,
            min_detection_confidence=0.2,
            min_tracking_confidence=0.2,
        )

        # Constants
        self.min_frames = 5
        self.num_frames = 210

    def get_frames(self, video_name, start_frame, end_frame):
        video_path = os.path.join(self.videos_path, video_name + ".avi")
        cap = cv2.VideoCapture(video_path)
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        if not cap.isOpened():
            raise FileNotFoundError(f"Video file not found: {video_path}")
    
        frames = []
        for frame_i in range(start_frame, end_frame):
            ret, frame = cap.read()
            if not ret:
                break
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(frame)
        cap.release()
        return frames

    def get_annotation(self, idx):
        info = self.annots[idx]
        video_name, label, label_id, start_frame, end_frame, num_frames = info
        frames = self.get_frames(video_name, start_frame, end_frame)
        return frames, label_id

    # Extracts skeletons using mediapipe from a list of frames, removes missing frames at the start and end, 
    # and interpolates frames in the middle. Will repeat frames (upsample) or downsample to reach exactly self.num_frames.
    def extract_skeleton_sequence(self, frames, annot_idx):
        seq = []
        missing = []

        first_valid = -1
        last_valid = -1
        avail = 0
        for i, frame in enumerate(frames):
            result = self.hands.process(frame)
    
            if result.multi_hand_landmarks:
                landmarks = result.multi_hand_landmarks[0].landmark
                seq.append(torch.tensor([[lm.x, lm.y, lm.z] for lm in landmarks], dtype=torch.float32))
                
                if first_valid == -1:
                    first_valid = i
                last_valid = i
                avail += 1
            else:
                seq.append(None)
                missing.append(i)
    
        # If too few frames, discard
        if avail < self.min_frames:
            return None
    
        # Slice seq to remove missing frames at start and end
        seq = seq[first_valid : last_valid + 1]
        
        # Interpolate missing frames in the middle
        prev = 0
        for i in range(1, len(seq)):
            if seq[i] is not None:
                for j in range(prev + 1, i):       
                    # Linear interpolation
                    alpha = (j - prev) / (i - prev)
                    seq[j] = (1 - alpha) * seq[prev] + alpha * seq[i]
                prev = i
    
        
        seq = torch.stack(seq)
        T = seq.shape[0]
        
        if T == self.num_frames:
            return seq
    
        if T > self.num_frames:
            # Downsample evenly
            idx = torch.linspace(0, T - 1, self.num_frames).long()
            seq = seq[idx]
        else:
            # Upsample by cycling frames instead of repeating last
            extra = self.num_frames - T
            cycle_idx = torch.arange(extra) % T
            pad = seq[cycle_idx]
            seq = torch.cat([seq, pad], dim=0)
    
        return seq

    def extract_all_skeletons(self):
        metadata = {"samples": []}
        skel_list = []

        valid_cnt = 0
        for idx, info in enumerate(self.annots):
            video_name, label, label_id, start_frame, end_frame, num_frames = info
            
            # Extract frames
            frames = self.get_frames(video_name, start_frame, end_frame)
            
            # Extract skeletons and track missing
            skeleton_seq = self.extract_skeleton_sequence(frames, idx)
            
            # If video is missing too much data (can't extract skeletons), then discard
            if skeleton_seq is None:
                print(f"Discarded: {info}")
                continue

            assert skeleton_seq.shape[0] == self.num_frames
            skel_list.append(skeleton_seq)
            
            # Store metadata
            metadata["samples"].append({
                "idx": idx,
                "skel_idx": valid_cnt,
                "video": video_name,
                "label": label,
                "label_id": label_id,
                "start_frame": start_frame,
                "end_frame": end_frame,
                "num_frames": num_frames
            })
            valid_cnt += 1

            if idx > 0 and idx % 100 == 0:
                print(f"Processed {idx} gestures")

        # Save all skeletons as tensor
        skel_tensor = torch.stack(skel_list)
        torch.save(skel_tensor, os.path.join(self.out_path, "skeletons_tensor.pt"))
        
        # Save skeleton metadata
        meta_path = os.path.join(self.out_path, "skeleton_annots.json")
        with open(meta_path, "w") as f:
            json.dump(metadata, f, indent=2)

        print(f"Saved all skeletons and metadata to {self.dset_path}")
        print(f"Missing frames info saved to {missing_path}")

# %%
train_annots = read_annotations(os.path.join(annotations_path, "Annot_TrainList.txt"))
test_annots = read_annotations(os.path.join(annotations_path, "Annot_TestList.txt"))
print(len(train_annots), len(test_annots))
# Out:
# 4038 1609

# %%
gest_lens = np.array([info[-1] for info in train_annots])
plt.hist(gest_lens, bins=50)
plt.show()

# %%
train_dataset = IPNDataPreProcessor(train_annots, path, os.path.join(path, "train_skeletons"))
train_dataset.extract_all_skeletons()

# %%
train_dataset = IPNDataPreProcessor(test_annots, path, os.path.join(path, "test_skeletons"))
train_dataset.extract_all_skeletons()
# Out:
# I0000 00:00:1763172404.938768 204059605 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M4
# W0000 00:00:1763172404.956687 205874647 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1763172404.962784 205874647 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Discarded: ['1CM1_1_R__217', 'G03', 6, 1884, 1938, 55]
# Discarded: ['1CM1_1_R__217', 'G02', 5, 2861, 2906, 46]
# Discarded: ['1CM1_1_R__217', 'G08', 11, 3388, 3414, 27]
# Discarded: ['1CM1_1_R__218', 'D0X', 1, 1, 19, 19]
# Discarded: ['1CM1_1_R__218', 'G02', 5, 1041, 1074, 34]
# Discarded: ['1CM1_1_R__218', 'G07', 10, 1906, 1945, 40]
# Discarded: ['1CM1_1_R__218', 'G11', 14, 2491, 2543, 53]
# Discarded: ['1CM1_1_R__219', 'D0X', 1, 1, 21, 21]
# Discarded: ['1CM1_1_R__219', 'D0X', 1, 1131, 1500, 370]
# Discarded: ['1CM1_1_R__219', 'D0X', 1, 2682, 3016, 335]
# Discarded: ['1CM1_1_R__219', 'D0X', 1, 3865, 3921, 57]
# Discarded: ['1CM1_1_R__220', 'D0X', 1, 1, 25, 25]
# Processed 100 gestures
# Discarded: ['1CM1_1_R__220', 'D0X', 1, 3837, 3889, 53]
# Discarded: ['1CM1_2_R__222', 'D0X', 1, 1, 29, 29]
# Discarded: ['1CM1_2_R__222', 'D0X', 1, 1442, 1493, 52]
# Discarded: ['1CM1_2_R__222', 'D0X', 1, 2764, 2874, 111]
# Processed 200 gestures
# Discarded: ['1CM1_2_R__223', 'D0X', 1, 1034, 1059, 26]
# Discarded: ['1CM1_2_R__224', 'D0X', 1, 1580, 1786, 207]
# /opt/miniconda3/envs/dev/lib/python3.9/site-packages/matplotlib/animation.py:872: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# Processed 300 gestures
# Discarded: ['1CM1_3_R__225', 'D0X', 1, 4186, 4260, 75]
# Discarded: ['1CM1_3_R__226', 'D0X', 1, 4769, 4795, 27]
# Discarded: ['1CM1_3_R__228', 'D0X', 1, 4170, 4176, 7]
# Processed 400 gestures
# Discarded: ['1CM42_15_R__198', 'D0X', 1, 4426, 4465, 40]
# Discarded: ['1CM42_15_R__199', 'D0X', 1, 4220, 4243, 24]
# Discarded: ['1CM42_30_R__145', 'D0X', 1, 1, 63, 63]
# Processed 500 gestures
# Discarded: ['1CM42_30_R__145', 'D0X', 1, 3715, 3760, 46]
# Discarded: ['1CM42_30_R__148', 'D0X', 1, 1, 41, 41]
# Discarded: ['1CM42_31_R__129', 'D0X', 1, 1, 30, 30]
# Processed 600 gestures
# Processed 700 gestures
# Discarded: ['1CV12_12_R__89', 'D0X', 1, 3683, 3977, 295]
# Discarded: ['1CV12_12_R__89', 'D0X', 1, 4370, 4395, 26]
# Discarded: ['1CV12_12_R__90', 'D0X', 1, 1, 112, 112]
# Discarded: ['1CV12_12_R__91', 'D0X', 1, 1, 72, 72]
# Discarded: ['1CV12_12_R__92', 'D0X', 1, 1, 134, 134]
# Discarded: ['1CV12_12_R__92', 'D0X', 1, 4720, 4772, 53]
# Processed 800 gestures
# Processed 900 gestures
# Discarded: ['1CV12_15_R__103', 'D0X', 1, 3585, 3634, 50]
# Discarded: ['1CV12_15_R__104', 'D0X', 1, 1, 34, 34]
# Discarded: ['1CV12_21_R__109', 'D0X', 1, 1, 104, 104]
# Discarded: ['1CV12_21_R__110', 'D0X', 1, 1, 56, 56]
# Processed 1000 gestures
# Discarded: ['1CV12_21_R__111', 'D0X', 1, 1, 80, 80]
# Discarded: ['1CV12_21_R__112', 'D0X', 1, 1, 115, 115]
# Discarded: ['4CM11_13_R__29', 'D0X', 1, 1, 31, 31]
# Processed 1100 gestures
# Discarded: ['4CM11_13_R__31', 'D0X', 1, 1, 25, 25]
# Processed 1200 gestures
# Discarded: ['4CM11_18_R__45', 'D0X', 1, 3237, 3306, 70]
# Discarded: ['4CM11_18_R__45', 'D0X', 1, 3641, 3664, 24]
# Discarded: ['4CM11_18_R__46', 'D0X', 1, 3720, 3739, 20]
# Discarded: ['4CM11_18_R__47', 'D0X', 1, 1, 17, 17]
# Processed 1300 gestures
# Discarded: ['4CM11_18_R__47', 'D0X', 1, 2443, 2641, 199]
# Discarded: ['4CM11_18_R__47', 'D0X', 1, 3664, 3691, 28]
# Discarded: ['4CM11_18_R__48', 'D0X', 1, 3670, 3697, 28]
# Discarded: ['4CM11_20_R__41', 'D0X', 1, 1, 59, 59]
# Discarded: ['4CM11_20_R__41', 'D0X', 1, 3694, 3746, 53]
# Processed 1400 gestures
# Discarded: ['4CM11_20_R__43', 'D0X', 1, 3979, 4005, 27]
# Discarded: ['4CM11_20_R__44', 'D0X', 1, 1, 50, 50]
# Processed 1500 gestures
# Discarded: ['4CM11_24_L__63', 'D0X', 1, 1, 81, 81]
# Processed 1600 gestures
# Saved all skeletons and metadata to /Users/steventan/.cache/kagglehub/datasets/soumicksarker/ipn-hand-dataset/versions/7
# Missing frames info saved to /Users/steventan/.cache/kagglehub/datasets/soumicksarker/ipn-hand-dataset/versions/7/test_skeletons/missing_skeletons.json

# %%
# Edge list from Mediapipe HAND_CONNECTIONS

MEDIAPIPE_EDGES = [
    (0,1),(1,2),(2,3),(3,4),
    (0,5),(5,6),(6,7),(7,8),
    (0,9),(9,10),(10,11),(11,12),
    (0,13),(13,14),(14,15),(15,16),
    (0,17),(17,18),(18,19),(19,20),
]

def animate_skeleton_sequence(seq, interval=50):
    T = seq.shape[0]

    # Extract the first frame’s 2D positions
    first = seq[0][:, :2]

    plt.close('all')
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_subplot(111)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.invert_yaxis()
    ax.set_aspect('equal')
    ax.axis('off')

    scat = ax.scatter(first[:, 0], first[:, 1], s=20)

    lines = []
    for (a, b) in MEDIAPIPE_EDGES:
        ln, = ax.plot(
            [first[a,0], first[b,0]],
            [first[a,1], first[b,1]],
            linewidth=2
        )
        lines.append(ln)

    def update(i):
        joints = seq[i][:, :2]

        scat.set_offsets(joints)

        for ln, (a, b) in zip(lines, MEDIAPIPE_EDGES):
            ln.set_data(
                [joints[a,0], joints[b,0]],
                [joints[a,1], joints[b,1]]
            )

        return [scat] + lines

    ani = animation.FuncAnimation(
        fig, update, frames=T, interval=interval, blit=False
    )
    return ani

# %%
skel_data = torch.load(os.path.join(path, "train_skeletons/skeletons_tensor.pt"))

with open(os.path.join(path, "train_skeletons/skeleton_annots.json"), 'r') as file:
    skel_metadata = json.load(file)
skel_metadata
# Out:
# /var/folders/_1/ph20kymj4s9bnnn49x3mjlxr0000gn/T/ipykernel_24563/2474470438.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   skel_data = torch.load(os.path.join(path, "train_skeletons/skeletons_tensor.pt"))
# {'samples': [{'idx': 0,
#    'skel_idx': 0,
#    'video': '1CM1_4_R__229',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 18,
#    'end_frame': 55,
#    'num_frames': 38},
#   {'idx': 1,
#    'skel_idx': 1,
#    'video': '1CM1_4_R__229',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 56,
#    'end_frame': 284,
#    'num_frames': 229},
#   {'idx': 2,
#    'skel_idx': 2,
#    'video': '1CM1_4_R__229',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 285,
#    'end_frame': 308,
#    'num_frames': 24},
#   {'idx': 3,
#    'skel_idx': 3,
#    'video': '1CM1_4_R__229',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 309,
#    'end_frame': 502,
#    'num_frames': 194},
#   {'idx': 4,
#    'skel_idx': 4,
#    'video': '1CM1_4_R__229',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 503,
#    'end_frame': 544,
#    'num_frames': 42},
#   {'idx': 5,
#    'skel_idx': 5,
#    'video': '1CM1_4_R__229',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 545,
#    'end_frame': 857,
#    'num_frames': 313},
#   {'idx': 6,
#    'skel_idx': 6,
#    'video': '1CM1_4_R__229',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 858,
#    'end_frame': 899,
#    'num_frames': 42},
#   {'idx': 7,
#    'skel_idx': 7,
#    'video': '1CM1_4_R__229',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 900,
#    'end_frame': 1122,
#    'num_frames': 223},
#   {'idx': 8,
#    'skel_idx': 8,
#    'video': '1CM1_4_R__229',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1123,
#    'end_frame': 1432,
#    'num_frames': 310},
#   {'idx': 10,
#    'skel_idx': 9,
#    'video': '1CM1_4_R__229',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1458,
#    'end_frame': 1707,
#    'num_frames': 250},
#   {'idx': 11,
#    'skel_idx': 10,
#    'video': '1CM1_4_R__229',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1708,
#    'end_frame': 2042,
#    'num_frames': 335},
#   {'idx': 13,
#    'skel_idx': 11,
#    'video': '1CM1_4_R__229',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2078,
#    'end_frame': 2350,
#    'num_frames': 273},
#   {'idx': 14,
#    'skel_idx': 12,
#    'video': '1CM1_4_R__229',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 2351,
#    'end_frame': 2391,
#    'num_frames': 41},
#   {'idx': 15,
#    'skel_idx': 13,
#    'video': '1CM1_4_R__229',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2392,
#    'end_frame': 2603,
#    'num_frames': 212},
#   {'idx': 16,
#    'skel_idx': 14,
#    'video': '1CM1_4_R__229',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 2604,
#    'end_frame': 2646,
#    'num_frames': 43},
#   {'idx': 17,
#    'skel_idx': 15,
#    'video': '1CM1_4_R__229',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2647,
#    'end_frame': 2794,
#    'num_frames': 148},
#   {'idx': 18,
#    'skel_idx': 16,
#    'video': '1CM1_4_R__229',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2795,
#    'end_frame': 2993,
#    'num_frames': 199},
#   {'idx': 20,
#    'skel_idx': 17,
#    'video': '1CM1_4_R__229',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3030,
#    'end_frame': 3232,
#    'num_frames': 203},
#   {'idx': 21,
#    'skel_idx': 18,
#    'video': '1CM1_4_R__229',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 3233,
#    'end_frame': 3277,
#    'num_frames': 45},
#   {'idx': 22,
#    'skel_idx': 19,
#    'video': '1CM1_4_R__229',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3278,
#    'end_frame': 3645,
#    'num_frames': 368},
#   {'idx': 23,
#    'skel_idx': 20,
#    'video': '1CM1_4_R__229',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 3646,
#    'end_frame': 3676,
#    'num_frames': 31},
#   {'idx': 24,
#    'skel_idx': 21,
#    'video': '1CM1_4_R__229',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3677,
#    'end_frame': 3751,
#    'num_frames': 75},
#   {'idx': 25,
#    'skel_idx': 22,
#    'video': '1CM1_4_R__230',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1,
#    'end_frame': 24,
#    'num_frames': 24},
#   {'idx': 26,
#    'skel_idx': 23,
#    'video': '1CM1_4_R__230',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 25,
#    'end_frame': 65,
#    'num_frames': 41},
#   {'idx': 27,
#    'skel_idx': 24,
#    'video': '1CM1_4_R__230',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 66,
#    'end_frame': 347,
#    'num_frames': 282},
#   {'idx': 28,
#    'skel_idx': 25,
#    'video': '1CM1_4_R__230',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 348,
#    'end_frame': 381,
#    'num_frames': 34},
#   {'idx': 29,
#    'skel_idx': 26,
#    'video': '1CM1_4_R__230',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 382,
#    'end_frame': 579,
#    'num_frames': 198},
#   {'idx': 30,
#    'skel_idx': 27,
#    'video': '1CM1_4_R__230',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 580,
#    'end_frame': 616,
#    'num_frames': 37},
#   {'idx': 31,
#    'skel_idx': 28,
#    'video': '1CM1_4_R__230',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 617,
#    'end_frame': 860,
#    'num_frames': 244},
#   {'idx': 32,
#    'skel_idx': 29,
#    'video': '1CM1_4_R__230',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 861,
#    'end_frame': 901,
#    'num_frames': 41},
#   {'idx': 33,
#    'skel_idx': 30,
#    'video': '1CM1_4_R__230',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 902,
#    'end_frame': 1149,
#    'num_frames': 248},
#   {'idx': 34,
#    'skel_idx': 31,
#    'video': '1CM1_4_R__230',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 1150,
#    'end_frame': 1208,
#    'num_frames': 59},
#   {'idx': 35,
#    'skel_idx': 32,
#    'video': '1CM1_4_R__230',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1209,
#    'end_frame': 1542,
#    'num_frames': 334},
#   {'idx': 36,
#    'skel_idx': 33,
#    'video': '1CM1_4_R__230',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1543,
#    'end_frame': 1794,
#    'num_frames': 252},
#   {'idx': 38,
#    'skel_idx': 34,
#    'video': '1CM1_4_R__230',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1838,
#    'end_frame': 2116,
#    'num_frames': 279},
#   {'idx': 39,
#    'skel_idx': 35,
#    'video': '1CM1_4_R__230',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2117,
#    'end_frame': 2414,
#    'num_frames': 298},
#   {'idx': 41,
#    'skel_idx': 36,
#    'video': '1CM1_4_R__230',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2445,
#    'end_frame': 2725,
#    'num_frames': 281},
#   {'idx': 42,
#    'skel_idx': 37,
#    'video': '1CM1_4_R__230',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2726,
#    'end_frame': 2807,
#    'num_frames': 82},
#   {'idx': 43,
#    'skel_idx': 38,
#    'video': '1CM1_4_R__230',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 2808,
#    'end_frame': 2864,
#    'num_frames': 57},
#   {'idx': 44,
#    'skel_idx': 39,
#    'video': '1CM1_4_R__230',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2865,
#    'end_frame': 2973,
#    'num_frames': 109},
#   {'idx': 45,
#    'skel_idx': 40,
#    'video': '1CM1_4_R__230',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 2974,
#    'end_frame': 3006,
#    'num_frames': 33},
#   {'idx': 46,
#    'skel_idx': 41,
#    'video': '1CM1_4_R__230',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3007,
#    'end_frame': 3223,
#    'num_frames': 217},
#   {'idx': 47,
#    'skel_idx': 42,
#    'video': '1CM1_4_R__230',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 3224,
#    'end_frame': 3276,
#    'num_frames': 53},
#   {'idx': 48,
#    'skel_idx': 43,
#    'video': '1CM1_4_R__230',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3277,
#    'end_frame': 3583,
#    'num_frames': 307},
#   {'idx': 49,
#    'skel_idx': 44,
#    'video': '1CM1_4_R__230',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 3584,
#    'end_frame': 3632,
#    'num_frames': 49},
#   {'idx': 50,
#    'skel_idx': 45,
#    'video': '1CM1_4_R__230',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3633,
#    'end_frame': 3684,
#    'num_frames': 52},
#   {'idx': 51,
#    'skel_idx': 46,
#    'video': '1CM1_4_R__231',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1,
#    'end_frame': 22,
#    'num_frames': 22},
#   {'idx': 52,
#    'skel_idx': 47,
#    'video': '1CM1_4_R__231',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 23,
#    'end_frame': 73,
#    'num_frames': 51},
#   {'idx': 53,
#    'skel_idx': 48,
#    'video': '1CM1_4_R__231',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 74,
#    'end_frame': 281,
#    'num_frames': 208},
#   {'idx': 54,
#    'skel_idx': 49,
#    'video': '1CM1_4_R__231',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 282,
#    'end_frame': 333,
#    'num_frames': 52},
#   {'idx': 55,
#    'skel_idx': 50,
#    'video': '1CM1_4_R__231',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 334,
#    'end_frame': 538,
#    'num_frames': 205},
#   {'idx': 56,
#    'skel_idx': 51,
#    'video': '1CM1_4_R__231',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 539,
#    'end_frame': 565,
#    'num_frames': 27},
#   {'idx': 57,
#    'skel_idx': 52,
#    'video': '1CM1_4_R__231',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 566,
#    'end_frame': 804,
#    'num_frames': 239},
#   {'idx': 58,
#    'skel_idx': 53,
#    'video': '1CM1_4_R__231',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 805,
#    'end_frame': 843,
#    'num_frames': 39},
#   {'idx': 59,
#    'skel_idx': 54,
#    'video': '1CM1_4_R__231',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 844,
#    'end_frame': 1080,
#    'num_frames': 237},
#   {'idx': 60,
#    'skel_idx': 55,
#    'video': '1CM1_4_R__231',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1081,
#    'end_frame': 1291,
#    'num_frames': 211},
#   {'idx': 62,
#    'skel_idx': 56,
#    'video': '1CM1_4_R__231',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1326,
#    'end_frame': 1715,
#    'num_frames': 390},
#   {'idx': 63,
#    'skel_idx': 57,
#    'video': '1CM1_4_R__231',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 1716,
#    'end_frame': 1750,
#    'num_frames': 35},
#   {'idx': 64,
#    'skel_idx': 58,
#    'video': '1CM1_4_R__231',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1751,
#    'end_frame': 1958,
#    'num_frames': 208},
#   {'idx': 65,
#    'skel_idx': 59,
#    'video': '1CM1_4_R__231',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 1959,
#    'end_frame': 1988,
#    'num_frames': 30},
#   {'idx': 66,
#    'skel_idx': 60,
#    'video': '1CM1_4_R__231',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1989,
#    'end_frame': 2177,
#    'num_frames': 189},
#   {'idx': 67,
#    'skel_idx': 61,
#    'video': '1CM1_4_R__231',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2178,
#    'end_frame': 2431,
#    'num_frames': 254},
#   {'idx': 69,
#    'skel_idx': 62,
#    'video': '1CM1_4_R__231',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2469,
#    'end_frame': 2679,
#    'num_frames': 211},
#   {'idx': 70,
#    'skel_idx': 63,
#    'video': '1CM1_4_R__231',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2680,
#    'end_frame': 3052,
#    'num_frames': 373},
#   {'idx': 72,
#    'skel_idx': 64,
#    'video': '1CM1_4_R__231',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3091,
#    'end_frame': 3325,
#    'num_frames': 235},
#   {'idx': 73,
#    'skel_idx': 65,
#    'video': '1CM1_4_R__231',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 3326,
#    'end_frame': 3378,
#    'num_frames': 53},
#   {'idx': 74,
#    'skel_idx': 66,
#    'video': '1CM1_4_R__231',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3379,
#    'end_frame': 3661,
#    'num_frames': 283},
#   {'idx': 75,
#    'skel_idx': 67,
#    'video': '1CM1_4_R__231',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 3662,
#    'end_frame': 3689,
#    'num_frames': 28},
#   {'idx': 76,
#    'skel_idx': 68,
#    'video': '1CM1_4_R__231',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3690,
#    'end_frame': 3747,
#    'num_frames': 58},
#   {'idx': 77,
#    'skel_idx': 69,
#    'video': '1CM1_4_R__232',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1,
#    'end_frame': 9,
#    'num_frames': 9},
#   {'idx': 78,
#    'skel_idx': 70,
#    'video': '1CM1_4_R__232',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 10,
#    'end_frame': 37,
#    'num_frames': 28},
#   {'idx': 79,
#    'skel_idx': 71,
#    'video': '1CM1_4_R__232',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 38,
#    'end_frame': 318,
#    'num_frames': 281},
#   {'idx': 80,
#    'skel_idx': 72,
#    'video': '1CM1_4_R__232',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 319,
#    'end_frame': 375,
#    'num_frames': 57},
#   {'idx': 81,
#    'skel_idx': 73,
#    'video': '1CM1_4_R__232',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 376,
#    'end_frame': 568,
#    'num_frames': 193},
#   {'idx': 82,
#    'skel_idx': 74,
#    'video': '1CM1_4_R__232',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 569,
#    'end_frame': 604,
#    'num_frames': 36},
#   {'idx': 83,
#    'skel_idx': 75,
#    'video': '1CM1_4_R__232',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 605,
#    'end_frame': 813,
#    'num_frames': 209},
#   {'idx': 84,
#    'skel_idx': 76,
#    'video': '1CM1_4_R__232',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 814,
#    'end_frame': 845,
#    'num_frames': 32},
#   {'idx': 85,
#    'skel_idx': 77,
#    'video': '1CM1_4_R__232',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 846,
#    'end_frame': 1083,
#    'num_frames': 238},
#   {'idx': 86,
#    'skel_idx': 78,
#    'video': '1CM1_4_R__232',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1084,
#    'end_frame': 1393,
#    'num_frames': 310},
#   {'idx': 88,
#    'skel_idx': 79,
#    'video': '1CM1_4_R__232',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1422,
#    'end_frame': 1684,
#    'num_frames': 263},
#   {'idx': 89,
#    'skel_idx': 80,
#    'video': '1CM1_4_R__232',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1685,
#    'end_frame': 1922,
#    'num_frames': 238},
#   {'idx': 91,
#    'skel_idx': 81,
#    'video': '1CM1_4_R__232',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1961,
#    'end_frame': 2283,
#    'num_frames': 323},
#   {'idx': 92,
#    'skel_idx': 82,
#    'video': '1CM1_4_R__232',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 2284,
#    'end_frame': 2337,
#    'num_frames': 54},
#   {'idx': 93,
#    'skel_idx': 83,
#    'video': '1CM1_4_R__232',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2338,
#    'end_frame': 2705,
#    'num_frames': 368},
#   {'idx': 94,
#    'skel_idx': 84,
#    'video': '1CM1_4_R__232',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2706,
#    'end_frame': 2928,
#    'num_frames': 223},
#   {'idx': 95,
#    'skel_idx': 85,
#    'video': '1CM1_4_R__232',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 2929,
#    'end_frame': 2980,
#    'num_frames': 52},
#   {'idx': 96,
#    'skel_idx': 86,
#    'video': '1CM1_4_R__232',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2981,
#    'end_frame': 3289,
#    'num_frames': 309},
#   {'idx': 97,
#    'skel_idx': 87,
#    'video': '1CM1_4_R__232',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 3290,
#    'end_frame': 3329,
#    'num_frames': 40},
#   {'idx': 98,
#    'skel_idx': 88,
#    'video': '1CM1_4_R__232',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3330,
#    'end_frame': 3541,
#    'num_frames': 212},
#   {'idx': 99,
#    'skel_idx': 89,
#    'video': '1CM1_4_R__232',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 3542,
#    'end_frame': 3567,
#    'num_frames': 26},
#   {'idx': 100,
#    'skel_idx': 90,
#    'video': '1CM1_4_R__232',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3568,
#    'end_frame': 3766,
#    'num_frames': 199},
#   {'idx': 101,
#    'skel_idx': 91,
#    'video': '1CM1_4_R__232',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 3767,
#    'end_frame': 3809,
#    'num_frames': 43},
#   {'idx': 102,
#    'skel_idx': 92,
#    'video': '1CM1_4_R__232',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3810,
#    'end_frame': 3858,
#    'num_frames': 49},
#   {'idx': 104,
#    'skel_idx': 93,
#    'video': '1CM42_11_R__205',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 35,
#    'end_frame': 76,
#    'num_frames': 42},
#   {'idx': 105,
#    'skel_idx': 94,
#    'video': '1CM42_11_R__205',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 77,
#    'end_frame': 302,
#    'num_frames': 226},
#   {'idx': 106,
#    'skel_idx': 95,
#    'video': '1CM42_11_R__205',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 303,
#    'end_frame': 361,
#    'num_frames': 59},
#   {'idx': 107,
#    'skel_idx': 96,
#    'video': '1CM42_11_R__205',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 362,
#    'end_frame': 586,
#    'num_frames': 225},
#   {'idx': 108,
#    'skel_idx': 97,
#    'video': '1CM42_11_R__205',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 587,
#    'end_frame': 629,
#    'num_frames': 43},
#   {'idx': 109,
#    'skel_idx': 98,
#    'video': '1CM42_11_R__205',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 630,
#    'end_frame': 944,
#    'num_frames': 315},
#   {'idx': 110,
#    'skel_idx': 99,
#    'video': '1CM42_11_R__205',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 945,
#    'end_frame': 987,
#    'num_frames': 43},
#   {'idx': 111,
#    'skel_idx': 100,
#    'video': '1CM42_11_R__205',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 988,
#    'end_frame': 1214,
#    'num_frames': 227},
#   {'idx': 112,
#    'skel_idx': 101,
#    'video': '1CM42_11_R__205',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1215,
#    'end_frame': 1607,
#    'num_frames': 393},
#   {'idx': 113,
#    'skel_idx': 102,
#    'video': '1CM42_11_R__205',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 1608,
#    'end_frame': 1654,
#    'num_frames': 47},
#   {'idx': 114,
#    'skel_idx': 103,
#    'video': '1CM42_11_R__205',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1655,
#    'end_frame': 2000,
#    'num_frames': 346},
#   {'idx': 115,
#    'skel_idx': 104,
#    'video': '1CM42_11_R__205',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2001,
#    'end_frame': 2209,
#    'num_frames': 209},
#   {'idx': 116,
#    'skel_idx': 105,
#    'video': '1CM42_11_R__205',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 2210,
#    'end_frame': 2270,
#    'num_frames': 61},
#   {'idx': 117,
#    'skel_idx': 106,
#    'video': '1CM42_11_R__205',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2271,
#    'end_frame': 2545,
#    'num_frames': 275},
#   {'idx': 118,
#    'skel_idx': 107,
#    'video': '1CM42_11_R__205',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 2546,
#    'end_frame': 2612,
#    'num_frames': 67},
#   {'idx': 119,
#    'skel_idx': 108,
#    'video': '1CM42_11_R__205',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2613,
#    'end_frame': 2844,
#    'num_frames': 232},
#   {'idx': 120,
#    'skel_idx': 109,
#    'video': '1CM42_11_R__205',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 2845,
#    'end_frame': 2880,
#    'num_frames': 36},
#   {'idx': 121,
#    'skel_idx': 110,
#    'video': '1CM42_11_R__205',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2881,
#    'end_frame': 3097,
#    'num_frames': 217},
#   {'idx': 122,
#    'skel_idx': 111,
#    'video': '1CM42_11_R__205',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 3098,
#    'end_frame': 3144,
#    'num_frames': 47},
#   {'idx': 123,
#    'skel_idx': 112,
#    'video': '1CM42_11_R__205',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3145,
#    'end_frame': 3327,
#    'num_frames': 183},
#   {'idx': 124,
#    'skel_idx': 113,
#    'video': '1CM42_11_R__205',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3328,
#    'end_frame': 3471,
#    'num_frames': 144},
#   {'idx': 125,
#    'skel_idx': 114,
#    'video': '1CM42_11_R__205',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 3472,
#    'end_frame': 3532,
#    'num_frames': 61},
#   {'idx': 126,
#    'skel_idx': 115,
#    'video': '1CM42_11_R__205',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3533,
#    'end_frame': 3657,
#    'num_frames': 125},
#   {'idx': 127,
#    'skel_idx': 116,
#    'video': '1CM42_11_R__205',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 3658,
#    'end_frame': 3686,
#    'num_frames': 29},
#   {'idx': 128,
#    'skel_idx': 117,
#    'video': '1CM42_11_R__206',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1,
#    'end_frame': 45,
#    'num_frames': 45},
#   {'idx': 129,
#    'skel_idx': 118,
#    'video': '1CM42_11_R__206',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 46,
#    'end_frame': 140,
#    'num_frames': 95},
#   {'idx': 130,
#    'skel_idx': 119,
#    'video': '1CM42_11_R__206',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 141,
#    'end_frame': 506,
#    'num_frames': 366},
#   {'idx': 131,
#    'skel_idx': 120,
#    'video': '1CM42_11_R__206',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 507,
#    'end_frame': 580,
#    'num_frames': 74},
#   {'idx': 132,
#    'skel_idx': 121,
#    'video': '1CM42_11_R__206',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 581,
#    'end_frame': 817,
#    'num_frames': 237},
#   {'idx': 133,
#    'skel_idx': 122,
#    'video': '1CM42_11_R__206',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 818,
#    'end_frame': 911,
#    'num_frames': 94},
#   {'idx': 134,
#    'skel_idx': 123,
#    'video': '1CM42_11_R__206',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 912,
#    'end_frame': 1135,
#    'num_frames': 224},
#   {'idx': 135,
#    'skel_idx': 124,
#    'video': '1CM42_11_R__206',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 1136,
#    'end_frame': 1224,
#    'num_frames': 89},
#   {'idx': 136,
#    'skel_idx': 125,
#    'video': '1CM42_11_R__206',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1225,
#    'end_frame': 1409,
#    'num_frames': 185},
#   {'idx': 137,
#    'skel_idx': 126,
#    'video': '1CM42_11_R__206',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1410,
#    'end_frame': 1800,
#    'num_frames': 391},
#   {'idx': 138,
#    'skel_idx': 127,
#    'video': '1CM42_11_R__206',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 1801,
#    'end_frame': 1898,
#    'num_frames': 98},
#   {'idx': 139,
#    'skel_idx': 128,
#    'video': '1CM42_11_R__206',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1899,
#    'end_frame': 2129,
#    'num_frames': 231},
#   {'idx': 140,
#    'skel_idx': 129,
#    'video': '1CM42_11_R__206',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 2130,
#    'end_frame': 2214,
#    'num_frames': 85},
#   {'idx': 141,
#    'skel_idx': 130,
#    'video': '1CM42_11_R__206',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2215,
#    'end_frame': 2495,
#    'num_frames': 281},
#   {'idx': 142,
#    'skel_idx': 131,
#    'video': '1CM42_11_R__206',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 2496,
#    'end_frame': 2580,
#    'num_frames': 85},
#   {'idx': 143,
#    'skel_idx': 132,
#    'video': '1CM42_11_R__206',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2581,
#    'end_frame': 2848,
#    'num_frames': 268},
#   {'idx': 144,
#    'skel_idx': 133,
#    'video': '1CM42_11_R__206',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2849,
#    'end_frame': 3235,
#    'num_frames': 387},
#   {'idx': 145,
#    'skel_idx': 134,
#    'video': '1CM42_11_R__206',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 3236,
#    'end_frame': 3268,
#    'num_frames': 33},
#   {'idx': 146,
#    'skel_idx': 135,
#    'video': '1CM42_11_R__206',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3269,
#    'end_frame': 3602,
#    'num_frames': 334},
#   {'idx': 147,
#    'skel_idx': 136,
#    'video': '1CM42_11_R__206',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3603,
#    'end_frame': 3859,
#    'num_frames': 257},
#   {'idx': 148,
#    'skel_idx': 137,
#    'video': '1CM42_11_R__206',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 3860,
#    'end_frame': 3957,
#    'num_frames': 98},
#   {'idx': 149,
#    'skel_idx': 138,
#    'video': '1CM42_11_R__206',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3958,
#    'end_frame': 4169,
#    'num_frames': 212},
#   {'idx': 150,
#    'skel_idx': 139,
#    'video': '1CM42_11_R__206',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 4170,
#    'end_frame': 4273,
#    'num_frames': 104},
#   {'idx': 151,
#    'skel_idx': 140,
#    'video': '1CM42_11_R__206',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 4274,
#    'end_frame': 4586,
#    'num_frames': 313},
#   {'idx': 152,
#    'skel_idx': 141,
#    'video': '1CM42_11_R__206',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 4587,
#    'end_frame': 4653,
#    'num_frames': 67},
#   {'idx': 155,
#    'skel_idx': 142,
#    'video': '1CM42_11_R__207',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 37,
#    'end_frame': 108,
#    'num_frames': 72},
#   {'idx': 156,
#    'skel_idx': 143,
#    'video': '1CM42_11_R__207',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 109,
#    'end_frame': 322,
#    'num_frames': 214},
#   {'idx': 157,
#    'skel_idx': 144,
#    'video': '1CM42_11_R__207',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 323,
#    'end_frame': 367,
#    'num_frames': 45},
#   {'idx': 158,
#    'skel_idx': 145,
#    'video': '1CM42_11_R__207',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 368,
#    'end_frame': 605,
#    'num_frames': 238},
#   {'idx': 159,
#    'skel_idx': 146,
#    'video': '1CM42_11_R__207',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 606,
#    'end_frame': 656,
#    'num_frames': 51},
#   {'idx': 160,
#    'skel_idx': 147,
#    'video': '1CM42_11_R__207',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 657,
#    'end_frame': 973,
#    'num_frames': 317},
#   {'idx': 161,
#    'skel_idx': 148,
#    'video': '1CM42_11_R__207',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 974,
#    'end_frame': 1018,
#    'num_frames': 45},
#   {'idx': 162,
#    'skel_idx': 149,
#    'video': '1CM42_11_R__207',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1019,
#    'end_frame': 1288,
#    'num_frames': 270},
#   {'idx': 163,
#    'skel_idx': 150,
#    'video': '1CM42_11_R__207',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1289,
#    'end_frame': 1539,
#    'num_frames': 251},
#   {'idx': 164,
#    'skel_idx': 151,
#    'video': '1CM42_11_R__207',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 1540,
#    'end_frame': 1557,
#    'num_frames': 18},
#   {'idx': 165,
#    'skel_idx': 152,
#    'video': '1CM42_11_R__207',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1558,
#    'end_frame': 1864,
#    'num_frames': 307},
#   {'idx': 166,
#    'skel_idx': 153,
#    'video': '1CM42_11_R__207',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1865,
#    'end_frame': 2091,
#    'num_frames': 227},
#   {'idx': 167,
#    'skel_idx': 154,
#    'video': '1CM42_11_R__207',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 2092,
#    'end_frame': 2134,
#    'num_frames': 43},
#   {'idx': 168,
#    'skel_idx': 155,
#    'video': '1CM42_11_R__207',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2135,
#    'end_frame': 2354,
#    'num_frames': 220},
#   {'idx': 169,
#    'skel_idx': 156,
#    'video': '1CM42_11_R__207',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 2355,
#    'end_frame': 2420,
#    'num_frames': 66},
#   {'idx': 170,
#    'skel_idx': 157,
#    'video': '1CM42_11_R__207',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2421,
#    'end_frame': 2612,
#    'num_frames': 192},
#   {'idx': 171,
#    'skel_idx': 158,
#    'video': '1CM42_11_R__207',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2613,
#    'end_frame': 2784,
#    'num_frames': 172},
#   {'idx': 172,
#    'skel_idx': 159,
#    'video': '1CM42_11_R__207',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 2785,
#    'end_frame': 2856,
#    'num_frames': 72},
#   {'idx': 173,
#    'skel_idx': 160,
#    'video': '1CM42_11_R__207',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2857,
#    'end_frame': 3113,
#    'num_frames': 257},
#   {'idx': 174,
#    'skel_idx': 161,
#    'video': '1CM42_11_R__207',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 3114,
#    'end_frame': 3170,
#    'num_frames': 57},
#   {'idx': 175,
#    'skel_idx': 162,
#    'video': '1CM42_11_R__207',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3171,
#    'end_frame': 3402,
#    'num_frames': 232},
#   {'idx': 176,
#    'skel_idx': 163,
#    'video': '1CM42_11_R__207',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 3403,
#    'end_frame': 3444,
#    'num_frames': 42},
#   {'idx': 177,
#    'skel_idx': 164,
#    'video': '1CM42_11_R__207',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3445,
#    'end_frame': 3640,
#    'num_frames': 196},
#   {'idx': 178,
#    'skel_idx': 165,
#    'video': '1CM42_11_R__207',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 3641,
#    'end_frame': 3682,
#    'num_frames': 42},
#   {'idx': 179,
#    'skel_idx': 166,
#    'video': '1CM42_11_R__208',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1,
#    'end_frame': 30,
#    'num_frames': 30},
#   {'idx': 180,
#    'skel_idx': 167,
#    'video': '1CM42_11_R__208',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 31,
#    'end_frame': 80,
#    'num_frames': 50},
#   {'idx': 181,
#    'skel_idx': 168,
#    'video': '1CM42_11_R__208',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 81,
#    'end_frame': 406,
#    'num_frames': 326},
#   {'idx': 182,
#    'skel_idx': 169,
#    'video': '1CM42_11_R__208',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 407,
#    'end_frame': 456,
#    'num_frames': 50},
#   {'idx': 183,
#    'skel_idx': 170,
#    'video': '1CM42_11_R__208',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 457,
#    'end_frame': 732,
#    'num_frames': 276},
#   {'idx': 184,
#    'skel_idx': 171,
#    'video': '1CM42_11_R__208',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 733,
#    'end_frame': 789,
#    'num_frames': 57},
#   {'idx': 185,
#    'skel_idx': 172,
#    'video': '1CM42_11_R__208',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 790,
#    'end_frame': 1008,
#    'num_frames': 219},
#   {'idx': 186,
#    'skel_idx': 173,
#    'video': '1CM42_11_R__208',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1009,
#    'end_frame': 1224,
#    'num_frames': 216},
#   {'idx': 187,
#    'skel_idx': 174,
#    'video': '1CM42_11_R__208',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 1225,
#    'end_frame': 1280,
#    'num_frames': 56},
#   {'idx': 188,
#    'skel_idx': 175,
#    'video': '1CM42_11_R__208',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1281,
#    'end_frame': 1495,
#    'num_frames': 215},
#   {'idx': 189,
#    'skel_idx': 176,
#    'video': '1CM42_11_R__208',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1496,
#    'end_frame': 1742,
#    'num_frames': 247},
#   {'idx': 190,
#    'skel_idx': 177,
#    'video': '1CM42_11_R__208',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 1743,
#    'end_frame': 1804,
#    'num_frames': 62},
#   {'idx': 191,
#    'skel_idx': 178,
#    'video': '1CM42_11_R__208',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1805,
#    'end_frame': 2067,
#    'num_frames': 263},
#   {'idx': 192,
#    'skel_idx': 179,
#    'video': '1CM42_11_R__208',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 2068,
#    'end_frame': 2123,
#    'num_frames': 56},
#   {'idx': 193,
#    'skel_idx': 180,
#    'video': '1CM42_11_R__208',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2124,
#    'end_frame': 2348,
#    'num_frames': 225},
#   {'idx': 194,
#    'skel_idx': 181,
#    'video': '1CM42_11_R__208',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 2349,
#    'end_frame': 2400,
#    'num_frames': 52},
#   {'idx': 195,
#    'skel_idx': 182,
#    'video': '1CM42_11_R__208',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2401,
#    'end_frame': 2675,
#    'num_frames': 275},
#   {'idx': 196,
#    'skel_idx': 183,
#    'video': '1CM42_11_R__208',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2676,
#    'end_frame': 2885,
#    'num_frames': 210},
#   {'idx': 197,
#    'skel_idx': 184,
#    'video': '1CM42_11_R__208',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 2886,
#    'end_frame': 2943,
#    'num_frames': 58},
#   {'idx': 198,
#    'skel_idx': 185,
#    'video': '1CM42_11_R__208',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2944,
#    'end_frame': 3158,
#    'num_frames': 215},
#   {'idx': 199,
#    'skel_idx': 186,
#    'video': '1CM42_11_R__208',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 3159,
#    'end_frame': 3204,
#    'num_frames': 46},
#   {'idx': 200,
#    'skel_idx': 187,
#    'video': '1CM42_11_R__208',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3205,
#    'end_frame': 3421,
#    'num_frames': 217},
#   {'idx': 201,
#    'skel_idx': 188,
#    'video': '1CM42_11_R__208',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 3422,
#    'end_frame': 3469,
#    'num_frames': 48},
#   {'idx': 202,
#    'skel_idx': 189,
#    'video': '1CM42_11_R__208',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3470,
#    'end_frame': 3638,
#    'num_frames': 169},
#   {'idx': 203,
#    'skel_idx': 190,
#    'video': '1CM42_11_R__208',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 3639,
#    'end_frame': 3664,
#    'num_frames': 26},
#   {'idx': 204,
#    'skel_idx': 191,
#    'video': '1CM42_12_R__157',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 1,
#    'end_frame': 143,
#    'num_frames': 143},
#   {'idx': 205,
#    'skel_idx': 192,
#    'video': '1CM42_12_R__157',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 144,
#    'end_frame': 338,
#    'num_frames': 195},
#   {'idx': 206,
#    'skel_idx': 193,
#    'video': '1CM42_12_R__157',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 339,
#    'end_frame': 420,
#    'num_frames': 82},
#   {'idx': 207,
#    'skel_idx': 194,
#    'video': '1CM42_12_R__157',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 421,
#    'end_frame': 608,
#    'num_frames': 188},
#   {'idx': 208,
#    'skel_idx': 195,
#    'video': '1CM42_12_R__157',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 609,
#    'end_frame': 660,
#    'num_frames': 52},
#   {'idx': 209,
#    'skel_idx': 196,
#    'video': '1CM42_12_R__157',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 661,
#    'end_frame': 883,
#    'num_frames': 223},
#   {'idx': 210,
#    'skel_idx': 197,
#    'video': '1CM42_12_R__157',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 884,
#    'end_frame': 967,
#    'num_frames': 84},
#   {'idx': 211,
#    'skel_idx': 198,
#    'video': '1CM42_12_R__157',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 968,
#    'end_frame': 1154,
#    'num_frames': 187},
#   {'idx': 212,
#    'skel_idx': 199,
#    'video': '1CM42_12_R__157',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1155,
#    'end_frame': 1612,
#    'num_frames': 458},
#   {'idx': 213,
#    'skel_idx': 200,
#    'video': '1CM42_12_R__157',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 1613,
#    'end_frame': 1750,
#    'num_frames': 138},
#   {'idx': 214,
#    'skel_idx': 201,
#    'video': '1CM42_12_R__157',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1751,
#    'end_frame': 2014,
#    'num_frames': 264},
#   {'idx': 215,
#    'skel_idx': 202,
#    'video': '1CM42_12_R__157',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 2015,
#    'end_frame': 2198,
#    'num_frames': 184},
#   {'idx': 216,
#    'skel_idx': 203,
#    'video': '1CM42_12_R__157',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2199,
#    'end_frame': 2372,
#    'num_frames': 174},
#   {'idx': 217,
#    'skel_idx': 204,
#    'video': '1CM42_12_R__157',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2373,
#    'end_frame': 2685,
#    'num_frames': 313},
#   {'idx': 218,
#    'skel_idx': 205,
#    'video': '1CM42_12_R__157',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 2686,
#    'end_frame': 2841,
#    'num_frames': 156},
#   {'idx': 219,
#    'skel_idx': 206,
#    'video': '1CM42_12_R__157',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2842,
#    'end_frame': 3047,
#    'num_frames': 206},
#   {'idx': 220,
#    'skel_idx': 207,
#    'video': '1CM42_12_R__157',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 3048,
#    'end_frame': 3145,
#    'num_frames': 98},
#   {'idx': 221,
#    'skel_idx': 208,
#    'video': '1CM42_12_R__157',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3146,
#    'end_frame': 3327,
#    'num_frames': 182},
#   {'idx': 222,
#    'skel_idx': 209,
#    'video': '1CM42_12_R__157',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3328,
#    'end_frame': 3535,
#    'num_frames': 208},
#   {'idx': 223,
#    'skel_idx': 210,
#    'video': '1CM42_12_R__157',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 3536,
#    'end_frame': 3635,
#    'num_frames': 100},
#   {'idx': 224,
#    'skel_idx': 211,
#    'video': '1CM42_12_R__157',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3636,
#    'end_frame': 3813,
#    'num_frames': 178},
#   {'idx': 225,
#    'skel_idx': 212,
#    'video': '1CM42_12_R__157',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 3814,
#    'end_frame': 3897,
#    'num_frames': 84},
#   {'idx': 226,
#    'skel_idx': 213,
#    'video': '1CM42_12_R__157',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3898,
#    'end_frame': 4121,
#    'num_frames': 224},
#   {'idx': 227,
#    'skel_idx': 214,
#    'video': '1CM42_12_R__157',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 4122,
#    'end_frame': 4240,
#    'num_frames': 119},
#   {'idx': 228,
#    'skel_idx': 215,
#    'video': '1CM42_12_R__157',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 4241,
#    'end_frame': 4287,
#    'num_frames': 47},
#   {'idx': 229,
#    'skel_idx': 216,
#    'video': '1CM42_12_R__158',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1,
#    'end_frame': 37,
#    'num_frames': 37},
#   {'idx': 230,
#    'skel_idx': 217,
#    'video': '1CM42_12_R__158',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 38,
#    'end_frame': 160,
#    'num_frames': 123},
#   {'idx': 231,
#    'skel_idx': 218,
#    'video': '1CM42_12_R__158',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 161,
#    'end_frame': 382,
#    'num_frames': 222},
#   {'idx': 232,
#    'skel_idx': 219,
#    'video': '1CM42_12_R__158',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 383,
#    'end_frame': 512,
#    'num_frames': 130},
#   {'idx': 233,
#    'skel_idx': 220,
#    'video': '1CM42_12_R__158',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 513,
#    'end_frame': 724,
#    'num_frames': 212},
#   {'idx': 234,
#    'skel_idx': 221,
#    'video': '1CM42_12_R__158',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 725,
#    'end_frame': 828,
#    'num_frames': 104},
#   {'idx': 235,
#    'skel_idx': 222,
#    'video': '1CM42_12_R__158',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 829,
#    'end_frame': 1047,
#    'num_frames': 219},
#   {'idx': 236,
#    'skel_idx': 223,
#    'video': '1CM42_12_R__158',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 1048,
#    'end_frame': 1171,
#    'num_frames': 124},
#   {'idx': 237,
#    'skel_idx': 224,
#    'video': '1CM42_12_R__158',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1172,
#    'end_frame': 1387,
#    'num_frames': 216},
#   {'idx': 238,
#    'skel_idx': 225,
#    'video': '1CM42_12_R__158',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 1388,
#    'end_frame': 1527,
#    'num_frames': 140},
#   {'idx': 239,
#    'skel_idx': 226,
#    'video': '1CM42_12_R__158',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1528,
#    'end_frame': 1743,
#    'num_frames': 216},
#   {'idx': 240,
#    'skel_idx': 227,
#    'video': '1CM42_12_R__158',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1744,
#    'end_frame': 2038,
#    'num_frames': 295},
#   {'idx': 241,
#    'skel_idx': 228,
#    'video': '1CM42_12_R__158',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 2039,
#    'end_frame': 2181,
#    'num_frames': 143},
#   {'idx': 242,
#    'skel_idx': 229,
#    'video': '1CM42_12_R__158',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2182,
#    'end_frame': 2399,
#    'num_frames': 218},
#   {'idx': 243,
#    'skel_idx': 230,
#    'video': '1CM42_12_R__158',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2400,
#    'end_frame': 2725,
#    'num_frames': 326},
#   {'idx': 244,
#    'skel_idx': 231,
#    'video': '1CM42_12_R__158',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 2726,
#    'end_frame': 2829,
#    'num_frames': 104},
#   {'idx': 245,
#    'skel_idx': 232,
#    'video': '1CM42_12_R__158',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2830,
#    'end_frame': 3044,
#    'num_frames': 215},
#   {'idx': 246,
#    'skel_idx': 233,
#    'video': '1CM42_12_R__158',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3045,
#    'end_frame': 3301,
#    'num_frames': 257},
#   {'idx': 247,
#    'skel_idx': 234,
#    'video': '1CM42_12_R__158',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 3302,
#    'end_frame': 3405,
#    'num_frames': 104},
#   {'idx': 248,
#    'skel_idx': 235,
#    'video': '1CM42_12_R__158',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3406,
#    'end_frame': 3632,
#    'num_frames': 227},
#   {'idx': 249,
#    'skel_idx': 236,
#    'video': '1CM42_12_R__158',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 3633,
#    'end_frame': 3759,
#    'num_frames': 127},
#   {'idx': 250,
#    'skel_idx': 237,
#    'video': '1CM42_12_R__158',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3760,
#    'end_frame': 3990,
#    'num_frames': 231},
#   {'idx': 251,
#    'skel_idx': 238,
#    'video': '1CM42_12_R__158',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 3991,
#    'end_frame': 4107,
#    'num_frames': 117},
#   {'idx': 252,
#    'skel_idx': 239,
#    'video': '1CM42_12_R__158',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 4108,
#    'end_frame': 4337,
#    'num_frames': 230},
#   {'idx': 253,
#    'skel_idx': 240,
#    'video': '1CM42_12_R__158',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 4338,
#    'end_frame': 4394,
#    'num_frames': 57},
#   {'idx': 254,
#    'skel_idx': 241,
#    'video': '1CM42_12_R__158',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 4395,
#    'end_frame': 4476,
#    'num_frames': 82},
#   {'idx': 255,
#    'skel_idx': 242,
#    'video': '1CM42_12_R__159',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1,
#    'end_frame': 31,
#    'num_frames': 31},
#   {'idx': 256,
#    'skel_idx': 243,
#    'video': '1CM42_12_R__159',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 32,
#    'end_frame': 146,
#    'num_frames': 115},
#   {'idx': 257,
#    'skel_idx': 244,
#    'video': '1CM42_12_R__159',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 147,
#    'end_frame': 351,
#    'num_frames': 205},
#   {'idx': 258,
#    'skel_idx': 245,
#    'video': '1CM42_12_R__159',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 352,
#    'end_frame': 469,
#    'num_frames': 118},
#   {'idx': 259,
#    'skel_idx': 246,
#    'video': '1CM42_12_R__159',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 470,
#    'end_frame': 682,
#    'num_frames': 213},
#   {'idx': 260,
#    'skel_idx': 247,
#    'video': '1CM42_12_R__159',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 683,
#    'end_frame': 827,
#    'num_frames': 145},
#   {'idx': 261,
#    'skel_idx': 248,
#    'video': '1CM42_12_R__159',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 828,
#    'end_frame': 1053,
#    'num_frames': 226},
#   {'idx': 262,
#    'skel_idx': 249,
#    'video': '1CM42_12_R__159',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 1054,
#    'end_frame': 1192,
#    'num_frames': 139},
#   {'idx': 263,
#    'skel_idx': 250,
#    'video': '1CM42_12_R__159',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1193,
#    'end_frame': 1420,
#    'num_frames': 228},
#   {'idx': 264,
#    'skel_idx': 251,
#    'video': '1CM42_12_R__159',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 1421,
#    'end_frame': 1563,
#    'num_frames': 143},
#   {'idx': 265,
#    'skel_idx': 252,
#    'video': '1CM42_12_R__159',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1564,
#    'end_frame': 1792,
#    'num_frames': 229},
#   {'idx': 266,
#    'skel_idx': 253,
#    'video': '1CM42_12_R__159',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1793,
#    'end_frame': 2004,
#    'num_frames': 212},
#   {'idx': 267,
#    'skel_idx': 254,
#    'video': '1CM42_12_R__159',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 2005,
#    'end_frame': 2178,
#    'num_frames': 174},
#   {'idx': 268,
#    'skel_idx': 255,
#    'video': '1CM42_12_R__159',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2179,
#    'end_frame': 2382,
#    'num_frames': 204},
#   {'idx': 269,
#    'skel_idx': 256,
#    'video': '1CM42_12_R__159',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2383,
#    'end_frame': 2605,
#    'num_frames': 223},
#   {'idx': 270,
#    'skel_idx': 257,
#    'video': '1CM42_12_R__159',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 2606,
#    'end_frame': 2689,
#    'num_frames': 84},
#   {'idx': 271,
#    'skel_idx': 258,
#    'video': '1CM42_12_R__159',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2690,
#    'end_frame': 2955,
#    'num_frames': 266},
#   {'idx': 272,
#    'skel_idx': 259,
#    'video': '1CM42_12_R__159',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 2956,
#    'end_frame': 3106,
#    'num_frames': 151},
#   {'idx': 273,
#    'skel_idx': 260,
#    'video': '1CM42_12_R__159',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3107,
#    'end_frame': 3308,
#    'num_frames': 202},
#   {'idx': 274,
#    'skel_idx': 261,
#    'video': '1CM42_12_R__159',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 3309,
#    'end_frame': 3447,
#    'num_frames': 139},
#   {'idx': 275,
#    'skel_idx': 262,
#    'video': '1CM42_12_R__159',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3448,
#    'end_frame': 3651,
#    'num_frames': 204},
#   {'idx': 276,
#    'skel_idx': 263,
#    'video': '1CM42_12_R__159',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3652,
#    'end_frame': 3922,
#    'num_frames': 271},
#   {'idx': 277,
#    'skel_idx': 264,
#    'video': '1CM42_12_R__159',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 3923,
#    'end_frame': 4082,
#    'num_frames': 160},
#   {'idx': 278,
#    'skel_idx': 265,
#    'video': '1CM42_12_R__159',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 4083,
#    'end_frame': 4274,
#    'num_frames': 192},
#   {'idx': 279,
#    'skel_idx': 266,
#    'video': '1CM42_12_R__159',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 4275,
#    'end_frame': 4306,
#    'num_frames': 32},
#   {'idx': 280,
#    'skel_idx': 267,
#    'video': '1CM42_12_R__159',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 4307,
#    'end_frame': 4383,
#    'num_frames': 77},
#   {'idx': 281,
#    'skel_idx': 268,
#    'video': '1CM42_12_R__160',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1,
#    'end_frame': 29,
#    'num_frames': 29},
#   {'idx': 282,
#    'skel_idx': 269,
#    'video': '1CM42_12_R__160',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 30,
#    'end_frame': 143,
#    'num_frames': 114},
#   {'idx': 283,
#    'skel_idx': 270,
#    'video': '1CM42_12_R__160',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 144,
#    'end_frame': 349,
#    'num_frames': 206},
#   {'idx': 284,
#    'skel_idx': 271,
#    'video': '1CM42_12_R__160',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 350,
#    'end_frame': 466,
#    'num_frames': 117},
#   {'idx': 285,
#    'skel_idx': 272,
#    'video': '1CM42_12_R__160',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 467,
#    'end_frame': 663,
#    'num_frames': 197},
#   {'idx': 286,
#    'skel_idx': 273,
#    'video': '1CM42_12_R__160',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 664,
#    'end_frame': 791,
#    'num_frames': 128},
#   {'idx': 287,
#    'skel_idx': 274,
#    'video': '1CM42_12_R__160',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 792,
#    'end_frame': 967,
#    'num_frames': 176},
#   {'idx': 288,
#    'skel_idx': 275,
#    'video': '1CM42_12_R__160',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 968,
#    'end_frame': 1105,
#    'num_frames': 138},
#   {'idx': 289,
#    'skel_idx': 276,
#    'video': '1CM42_12_R__160',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1106,
#    'end_frame': 1329,
# ...
#    'skel_idx': 906,
#    'video': '1CM42_3_R__193',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 98,
#    'end_frame': 407,
#    'num_frames': 310},
#   {'idx': 931,
#    'skel_idx': 907,
#    'video': '1CM42_3_R__193',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 408,
#    'end_frame': 467,
#    'num_frames': 60},
#   {'idx': 932,
#    'skel_idx': 908,
#    'video': '1CM42_3_R__193',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 468,
#    'end_frame': 684,
#    'num_frames': 217},
#   {'idx': 933,
#    'skel_idx': 909,
#    'video': '1CM42_3_R__193',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 685,
#    'end_frame': 745,
#    'num_frames': 61},
#   {'idx': 934,
#    'skel_idx': 910,
#    'video': '1CM42_3_R__193',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 746,
#    'end_frame': 966,
#    'num_frames': 221},
#   {'idx': 935,
#    'skel_idx': 911,
#    'video': '1CM42_3_R__193',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 967,
#    'end_frame': 1017,
#    'num_frames': 51},
#   {'idx': 936,
#    'skel_idx': 912,
#    'video': '1CM42_3_R__193',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1018,
#    'end_frame': 1284,
#    'num_frames': 267},
#   {'idx': 937,
#    'skel_idx': 913,
#    'video': '1CM42_3_R__193',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1285,
#    'end_frame': 1579,
#    'num_frames': 295},
#   {'idx': 938,
#    'skel_idx': 914,
#    'video': '1CM42_3_R__193',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 1580,
#    'end_frame': 1670,
#    'num_frames': 91},
#   {'idx': 939,
#    'skel_idx': 915,
#    'video': '1CM42_3_R__193',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1671,
#    'end_frame': 1872,
#    'num_frames': 202},
#   {'idx': 940,
#    'skel_idx': 916,
#    'video': '1CM42_3_R__193',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 1873,
#    'end_frame': 1915,
#    'num_frames': 43},
#   {'idx': 941,
#    'skel_idx': 917,
#    'video': '1CM42_3_R__193',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1916,
#    'end_frame': 2146,
#    'num_frames': 231},
#   {'idx': 942,
#    'skel_idx': 918,
#    'video': '1CM42_3_R__193',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2147,
#    'end_frame': 2536,
#    'num_frames': 390},
#   {'idx': 943,
#    'skel_idx': 919,
#    'video': '1CM42_3_R__193',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 2537,
#    'end_frame': 2617,
#    'num_frames': 81},
#   {'idx': 944,
#    'skel_idx': 920,
#    'video': '1CM42_3_R__193',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2618,
#    'end_frame': 2868,
#    'num_frames': 251},
#   {'idx': 945,
#    'skel_idx': 921,
#    'video': '1CM42_3_R__193',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2869,
#    'end_frame': 3036,
#    'num_frames': 168},
#   {'idx': 946,
#    'skel_idx': 922,
#    'video': '1CM42_3_R__193',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 3037,
#    'end_frame': 3110,
#    'num_frames': 74},
#   {'idx': 947,
#    'skel_idx': 923,
#    'video': '1CM42_3_R__193',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3111,
#    'end_frame': 3342,
#    'num_frames': 232},
#   {'idx': 948,
#    'skel_idx': 924,
#    'video': '1CM42_3_R__193',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 3343,
#    'end_frame': 3418,
#    'num_frames': 76},
#   {'idx': 949,
#    'skel_idx': 925,
#    'video': '1CM42_3_R__193',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3419,
#    'end_frame': 3610,
#    'num_frames': 192},
#   {'idx': 950,
#    'skel_idx': 926,
#    'video': '1CM42_3_R__193',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 3611,
#    'end_frame': 3686,
#    'num_frames': 76},
#   {'idx': 951,
#    'skel_idx': 927,
#    'video': '1CM42_3_R__193',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3687,
#    'end_frame': 3944,
#    'num_frames': 258},
#   {'idx': 952,
#    'skel_idx': 928,
#    'video': '1CM42_3_R__193',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 3945,
#    'end_frame': 3994,
#    'num_frames': 50},
#   {'idx': 953,
#    'skel_idx': 929,
#    'video': '1CM42_3_R__193',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3995,
#    'end_frame': 4087,
#    'num_frames': 93},
#   {'idx': 954,
#    'skel_idx': 930,
#    'video': '1CM42_3_R__194',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1,
#    'end_frame': 15,
#    'num_frames': 15},
#   {'idx': 955,
#    'skel_idx': 931,
#    'video': '1CM42_3_R__194',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 16,
#    'end_frame': 72,
#    'num_frames': 57},
#   {'idx': 956,
#    'skel_idx': 932,
#    'video': '1CM42_3_R__194',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 73,
#    'end_frame': 378,
#    'num_frames': 306},
#   {'idx': 957,
#    'skel_idx': 933,
#    'video': '1CM42_3_R__194',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 379,
#    'end_frame': 458,
#    'num_frames': 80},
#   {'idx': 958,
#    'skel_idx': 934,
#    'video': '1CM42_3_R__194',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 459,
#    'end_frame': 671,
#    'num_frames': 213},
#   {'idx': 959,
#    'skel_idx': 935,
#    'video': '1CM42_3_R__194',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 672,
#    'end_frame': 754,
#    'num_frames': 83},
#   {'idx': 960,
#    'skel_idx': 936,
#    'video': '1CM42_3_R__194',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 755,
#    'end_frame': 961,
#    'num_frames': 207},
#   {'idx': 961,
#    'skel_idx': 937,
#    'video': '1CM42_3_R__194',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 962,
#    'end_frame': 1013,
#    'num_frames': 52},
#   {'idx': 962,
#    'skel_idx': 938,
#    'video': '1CM42_3_R__194',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1014,
#    'end_frame': 1228,
#    'num_frames': 215},
#   {'idx': 963,
#    'skel_idx': 939,
#    'video': '1CM42_3_R__194',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1229,
#    'end_frame': 1471,
#    'num_frames': 243},
#   {'idx': 964,
#    'skel_idx': 940,
#    'video': '1CM42_3_R__194',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 1472,
#    'end_frame': 1534,
#    'num_frames': 63},
#   {'idx': 965,
#    'skel_idx': 941,
#    'video': '1CM42_3_R__194',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1535,
#    'end_frame': 1805,
#    'num_frames': 271},
#   {'idx': 966,
#    'skel_idx': 942,
#    'video': '1CM42_3_R__194',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1806,
#    'end_frame': 2114,
#    'num_frames': 309},
#   {'idx': 967,
#    'skel_idx': 943,
#    'video': '1CM42_3_R__194',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 2115,
#    'end_frame': 2187,
#    'num_frames': 73},
#   {'idx': 968,
#    'skel_idx': 944,
#    'video': '1CM42_3_R__194',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2188,
#    'end_frame': 2436,
#    'num_frames': 249},
#   {'idx': 969,
#    'skel_idx': 945,
#    'video': '1CM42_3_R__194',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 2437,
#    'end_frame': 2504,
#    'num_frames': 68},
#   {'idx': 970,
#    'skel_idx': 946,
#    'video': '1CM42_3_R__194',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2505,
#    'end_frame': 2726,
#    'num_frames': 222},
#   {'idx': 971,
#    'skel_idx': 947,
#    'video': '1CM42_3_R__194',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2727,
#    'end_frame': 3016,
#    'num_frames': 290},
#   {'idx': 972,
#    'skel_idx': 948,
#    'video': '1CM42_3_R__194',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 3017,
#    'end_frame': 3080,
#    'num_frames': 64},
#   {'idx': 973,
#    'skel_idx': 949,
#    'video': '1CM42_3_R__194',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3081,
#    'end_frame': 3359,
#    'num_frames': 279},
#   {'idx': 974,
#    'skel_idx': 950,
#    'video': '1CM42_3_R__194',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 3360,
#    'end_frame': 3416,
#    'num_frames': 57},
#   {'idx': 975,
#    'skel_idx': 951,
#    'video': '1CM42_3_R__194',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3417,
#    'end_frame': 3594,
#    'num_frames': 178},
#   {'idx': 976,
#    'skel_idx': 952,
#    'video': '1CM42_3_R__194',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 3595,
#    'end_frame': 3662,
#    'num_frames': 68},
#   {'idx': 977,
#    'skel_idx': 953,
#    'video': '1CM42_3_R__194',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3663,
#    'end_frame': 3873,
#    'num_frames': 211},
#   {'idx': 978,
#    'skel_idx': 954,
#    'video': '1CM42_3_R__194',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 3874,
#    'end_frame': 3931,
#    'num_frames': 58},
#   {'idx': 979,
#    'skel_idx': 955,
#    'video': '1CM42_3_R__194',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3932,
#    'end_frame': 3976,
#    'num_frames': 45},
#   {'idx': 980,
#    'skel_idx': 956,
#    'video': '1CM42_3_R__195',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1,
#    'end_frame': 21,
#    'num_frames': 21},
#   {'idx': 981,
#    'skel_idx': 957,
#    'video': '1CM42_3_R__195',
#    'label': 'G05',
#    'label_id': 8,
#    'start_frame': 22,
#    'end_frame': 76,
#    'num_frames': 55},
#   {'idx': 982,
#    'skel_idx': 958,
#    'video': '1CM42_3_R__195',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 77,
#    'end_frame': 348,
#    'num_frames': 272},
#   {'idx': 983,
#    'skel_idx': 959,
#    'video': '1CM42_3_R__195',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 349,
#    'end_frame': 420,
#    'num_frames': 72},
#   {'idx': 984,
#    'skel_idx': 960,
#    'video': '1CM42_3_R__195',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 421,
#    'end_frame': 720,
#    'num_frames': 300},
#   {'idx': 985,
#    'skel_idx': 961,
#    'video': '1CM42_3_R__195',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 721,
#    'end_frame': 798,
#    'num_frames': 78},
#   {'idx': 986,
#    'skel_idx': 962,
#    'video': '1CM42_3_R__195',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 799,
#    'end_frame': 1114,
#    'num_frames': 316},
#   {'idx': 987,
#    'skel_idx': 963,
#    'video': '1CM42_3_R__195',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 1115,
#    'end_frame': 1200,
#    'num_frames': 86},
#   {'idx': 988,
#    'skel_idx': 964,
#    'video': '1CM42_3_R__195',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1201,
#    'end_frame': 1513,
#    'num_frames': 313},
#   {'idx': 989,
#    'skel_idx': 965,
#    'video': '1CM42_3_R__195',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1514,
#    'end_frame': 1768,
#    'num_frames': 255},
#   {'idx': 990,
#    'skel_idx': 966,
#    'video': '1CM42_3_R__195',
#    'label': 'G04',
#    'label_id': 7,
#    'start_frame': 1769,
#    'end_frame': 1842,
#    'num_frames': 74},
#   {'idx': 991,
#    'skel_idx': 967,
#    'video': '1CM42_3_R__195',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1843,
#    'end_frame': 2131,
#    'num_frames': 289},
#   {'idx': 992,
#    'skel_idx': 968,
#    'video': '1CM42_3_R__195',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2132,
#    'end_frame': 2440,
#    'num_frames': 309},
#   {'idx': 993,
#    'skel_idx': 969,
#    'video': '1CM42_3_R__195',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 2441,
#    'end_frame': 2484,
#    'num_frames': 44},
#   {'idx': 994,
#    'skel_idx': 970,
#    'video': '1CM42_3_R__195',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2485,
#    'end_frame': 2796,
#    'num_frames': 312},
#   {'idx': 995,
#    'skel_idx': 971,
#    'video': '1CM42_3_R__195',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 2797,
#    'end_frame': 2856,
#    'num_frames': 60},
#   {'idx': 996,
#    'skel_idx': 972,
#    'video': '1CM42_3_R__195',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 2857,
#    'end_frame': 3117,
#    'num_frames': 261},
#   {'idx': 997,
#    'skel_idx': 973,
#    'video': '1CM42_3_R__195',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 3118,
#    'end_frame': 3306,
#    'num_frames': 189},
#   {'idx': 998,
#    'skel_idx': 974,
#    'video': '1CM42_3_R__195',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 3307,
#    'end_frame': 3368,
#    'num_frames': 62},
#   {'idx': 999,
#    'skel_idx': 975,
#    'video': '1CM42_3_R__195',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3369,
#    'end_frame': 3626,
#    'num_frames': 258},
#   {'idx': 1000,
#    'skel_idx': 976,
#    'video': '1CM42_3_R__195',
#    'label': 'G06',
#    'label_id': 9,
#    'start_frame': 3627,
#    'end_frame': 3683,
#    'num_frames': 57},
#   {'idx': 1001,
#    'skel_idx': 977,
#    'video': '1CM42_3_R__195',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 3684,
#    'end_frame': 3875,
#    'num_frames': 192},
#   {'idx': 1002,
#    'skel_idx': 978,
#    'video': '1CM42_3_R__195',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 3876,
#    'end_frame': 3928,
#    'num_frames': 53},
#   {'idx': 1003,
#    'skel_idx': 979,
#    'video': '1CM42_3_R__195',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 3929,
#    'end_frame': 4137,
#    'num_frames': 209},
#   {'idx': 1004,
#    'skel_idx': 980,
#    'video': '1CM42_3_R__195',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 4138,
#    'end_frame': 4171,
#    'num_frames': 34},
#   {'idx': 1005,
#    'skel_idx': 981,
#    'video': '1CM42_3_R__195',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 4172,
#    'end_frame': 4188,
#    'num_frames': 17},
#   {'idx': 1006,
#    'skel_idx': 982,
#    'video': '1CM42_3_R__196',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1,
#    'end_frame': 14,
#    'num_frames': 14},
#   {'idx': 1007,
#    'skel_idx': 983,
#    'video': '1CM42_3_R__196',
#    'label': 'G10',
#    'label_id': 13,
#    'start_frame': 15,
#    'end_frame': 98,
#    'num_frames': 84},
#   {'idx': 1008,
#    'skel_idx': 984,
#    'video': '1CM42_3_R__196',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 99,
#    'end_frame': 355,
#    'num_frames': 257},
#   {'idx': 1009,
#    'skel_idx': 985,
#    'video': '1CM42_3_R__196',
#    'label': 'G01',
#    'label_id': 4,
#    'start_frame': 356,
#    'end_frame': 370,
#    'num_frames': 15},
#   {'idx': 1010,
#    'skel_idx': 986,
#    'video': '1CM42_3_R__196',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 371,
#    'end_frame': 603,
#    'num_frames': 233},
#   {'idx': 1011,
#    'skel_idx': 987,
#    'video': '1CM42_3_R__196',
#    'label': 'G09',
#    'label_id': 12,
#    'start_frame': 604,
#    'end_frame': 657,
#    'num_frames': 54},
#   {'idx': 1012,
#    'skel_idx': 988,
#    'video': '1CM42_3_R__196',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 658,
#    'end_frame': 840,
#    'num_frames': 183},
#   {'idx': 1013,
#    'skel_idx': 989,
#    'video': '1CM42_3_R__196',
#    'label': 'G07',
#    'label_id': 10,
#    'start_frame': 841,
#    'end_frame': 925,
#    'num_frames': 85},
#   {'idx': 1014,
#    'skel_idx': 990,
#    'video': '1CM42_3_R__196',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 926,
#    'end_frame': 1185,
#    'num_frames': 260},
#   {'idx': 1015,
#    'skel_idx': 991,
#    'video': '1CM42_3_R__196',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 1186,
#    'end_frame': 1405,
#    'num_frames': 220},
#   {'idx': 1016,
#    'skel_idx': 992,
#    'video': '1CM42_3_R__196',
#    'label': 'G11',
#    'label_id': 14,
#    'start_frame': 1406,
#    'end_frame': 1483,
#    'num_frames': 78},
#   {'idx': 1017,
#    'skel_idx': 993,
#    'video': '1CM42_3_R__196',
#    'label': 'B0A',
#    'label_id': 2,
#    'start_frame': 1484,
#    'end_frame': 1762,
#    'num_frames': 279},
#   {'idx': 1018,
#    'skel_idx': 994,
#    'video': '1CM42_3_R__196',
#    'label': 'G03',
#    'label_id': 6,
#    'start_frame': 1763,
#    'end_frame': 1813,
#    'num_frames': 51},
#   {'idx': 1019,
#    'skel_idx': 995,
#    'video': '1CM42_3_R__196',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 1814,
#    'end_frame': 2043,
#    'num_frames': 230},
#   {'idx': 1020,
#    'skel_idx': 996,
#    'video': '1CM42_3_R__196',
#    'label': 'G02',
#    'label_id': 5,
#    'start_frame': 2044,
#    'end_frame': 2078,
#    'num_frames': 35},
#   {'idx': 1021,
#    'skel_idx': 997,
#    'video': '1CM42_3_R__196',
#    'label': 'B0B',
#    'label_id': 3,
#    'start_frame': 2079,
#    'end_frame': 2293,
#    'num_frames': 215},
#   {'idx': 1022,
#    'skel_idx': 998,
#    'video': '1CM42_3_R__196',
#    'label': 'D0X',
#    'label_id': 1,
#    'start_frame': 2294,
#    'end_frame': 2644,
#    'num_frames': 351},
#   {'idx': 1023,
#    'skel_idx': 999,
#    'video': '1CM42_3_R__196',
#    'label': 'G08',
#    'label_id': 11,
#    'start_frame': 2645,
#    'end_frame': 2732,
#    'num_frames': 88},
#   ...]}

# %%
skel_idx = 1012
print(skel_metadata["samples"][skel_idx])
ani = animate_skeleton_sequence(skel_data[skel_idx])
HTML(ani.to_jshtml())
# Out:
# {'idx': 1036, 'skel_idx': 1012, 'video': '1CM42_4_R__185', 'label': 'B0A', 'label_id': 2, 'start_frame': 332, 'end_frame': 593, 'num_frames': 262}
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgdd90c0b9f2cc47bd9ebb3793065765ec">
#   <div class="anim-controls">
#     <input id="_anim_sliderdd90c0b9f2cc47bd9ebb3793065765ec" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animdd90c0b9f2cc47bd9ebb3793065765ec.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animdd90c0b9f2cc47bd9ebb3793065765ec.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animdd90c0b9f2cc47bd9ebb3793065765ec.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animdd90c0b9f2cc47bd9ebb3793065765ec.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animdd90c0b9f2cc47bd9ebb3793065765ec.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animdd90c0b9f2cc47bd9ebb3793065765ec.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animdd90c0b9f2cc47bd9ebb3793065765ec.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animdd90c0b9f2cc47bd9ebb3793065765ec.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animdd90c0b9f2cc47bd9ebb3793065765ec.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animdd90c0b9f2cc47bd9ebb3793065765ec.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectdd90c0b9f2cc47bd9ebb3793065765ec"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_dd90c0b9f2cc47bd9ebb3793065765ec"
#              >
#       <label for="_anim_radio1_dd90c0b9f2cc47bd9ebb3793065765ec">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_dd90c0b9f2cc47bd9ebb3793065765ec"
#              checked>
#       <label for="_anim_radio2_dd90c0b9f2cc47bd9ebb3793065765ec">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_dd90c0b9f2cc47bd9ebb3793065765ec"
#              >
#       <label for="_anim_radio3_dd90c0b9f2cc47bd9ebb3793065765ec">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgdd90c0b9f2cc47bd9ebb3793065765ec";
#     var slider_id = "_anim_sliderdd90c0b9f2cc47bd9ebb3793065765ec";
#     var loop_select_id = "_anim_loop_selectdd90c0b9f2cc47bd9ebb3793065765ec";
#     var frames = new Array(210);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8hTgPZAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAmrUlE
