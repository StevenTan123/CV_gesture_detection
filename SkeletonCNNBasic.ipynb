# %%
import os
import json
import math
import random
from tqdm import tqdm

import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F

# %%
# obtain skeletons + label

DSET_PATH = "/Users/steventan/.cache/kagglehub/datasets/soumicksarker/ipn-hand-dataset/versions/7"
TRAIN_PATH = os.path.join(DSET_PATH, "train_skeletons")
TEST_PATH = os.path.join(DSET_PATH, "test_skeletons")

def load_skel_data(path):
    skeletons = torch.load(os.path.join(path, "skeletons_tensor.pt"))  
    with open(os.path.join(path, "skeleton_annots.json"), "r") as f:
        metadata = json.load(f)
    return skeletons, metadata

train_skels, train_metadata = load_skel_data(TRAIN_PATH)
test_skels, test_metadata = load_skel_data(TEST_PATH)

train_skels = train_skels.permute(0, 3, 2, 1)
test_skels = test_skels.permute(0, 3, 2, 1)

# minus one to make 0-indexed
train_labels = torch.tensor(
    [sample["label_id"] - 1 for sample in train_metadata["samples"]],
    dtype=torch.long,
)
test_labels = torch.tensor(
    [sample["label_id"] - 1 for sample in test_metadata["samples"]],
    dtype=torch.long,
)

# filter out first 100 training datapoints since they aren't labelled well
train_skels = train_skels[100:]
train_labels = train_labels[100:]

num_classes = len(torch.unique(train_labels))

# sanity check stuff
print("Labels shape:", train_labels.shape)
print("Skeletons shape:", train_skels.shape)
print("Num classes:", num_classes)
# Out:
# Labels shape: torch.Size([3781])
# Skeletons shape: torch.Size([3781, 3, 21, 210])
# Num classes: 14
# /var/folders/_1/ph20kymj4s9bnnn49x3mjlxr0000gn/T/ipykernel_16378/1506344242.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   skeletons = torch.load(os.path.join(path, "skeletons_tensor.pt"))

# %%
train_ds = TensorDataset(train_skels, train_labels)
test_ds = TensorDataset(test_skels, test_labels)

batch_size = 32
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

print("Train samples:", len(train_ds))
print("Test samples:", len(test_ds))
# Out:
# Train samples: 3781
# Test samples: 1556

# %%
class MediapipeHandGestureCNN(nn.Module):
    def __init__(self, num_classes: int, in_channels: int = 3):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)

        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(64)

        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(128)
        self.bn5 = nn.BatchNorm2d(128)

        self.conv6 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.bn6 = nn.BatchNorm2d(256)
        self.bn7 = nn.BatchNorm2d(256)

        self.conv_dropout = nn.Dropout2d(p=0.3)
        self.dropout = nn.Dropout(p=0.5)
            
        self.fc = nn.Linear(256, num_classes)

        self.pool_time = nn.MaxPool2d(kernel_size=(1, 2))  # (joints stay, time halves)

    def forward(self, x):
        """
        x: (B, C, H, W) = (batch, channels, joints, time)
        """
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool_time(x)  # shrink time

        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.conv_dropout(x)
        x = self.pool_time(x)

        x = F.relu(self.bn4(self.conv4(x)))
        x = F.relu(self.bn5(self.conv5(x)))
        x = self.conv_dropout(x)
        x = self.pool_time(x)

        x = F.relu(self.bn6(self.conv6(x)))
        x = F.relu(self.bn7(self.conv7(x)))
        x = self.conv_dropout(x)
        x = self.pool_time(x)

        x = F.adaptive_avg_pool2d(x, output_size=1) 
        x = x.view(x.size(0), -1)                   

        x = self.dropout(x)
        
        logits = self.fc(x)                       
        return logits

# %%
# Set device
if torch.cuda.is_available():
    device = torch.device("cuda")
elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

print("Using device:", device)
# Out:
# Using device: mps

# %%
def augment_skeleton_sequence(seq: torch.Tensor,
                              scale_min=0.8, scale_max=1.2,
                              translate_min=-0.1, translate_max=0.1,
                              jitter_sigma=0.001,
                              jitter_smooth=0.9):
    """
    Augmentation for fixed-camera hand gesture skeletons.
    
    seq: Tensor (C, T, V) => (# channels, # frames, # joints)
    - Applies one global scale + translation to all frames (consistent camera)
    - Adds temporally-smoothed jitter (simulates detector noise)
    """

    C, T, V = seq.shape
    device = seq.device

    # Choose scale and translation
    scale = random.uniform(scale_min, scale_max)

    tx = random.uniform(translate_min, translate_max)
    ty = random.uniform(translate_min, translate_max)

    # Apply global affine transform
    seq_aug = seq.clone()
    seq_aug[:2, :, :] *= scale           # scale x, y
    seq_aug[0, :, :] += tx               # translate x
    seq_aug[1, :, :] += ty               # translate y

    # Smooth jitter
    if jitter_sigma > 0:
        # white noise base
        noise = torch.randn(C, T, V, device=device) * jitter_sigma

        # exponential smoothing along time dimension
        smooth = torch.zeros_like(noise)
        smooth[:, 0, :] = noise[:, 0, :]
        alpha = 1 - jitter_smooth  # smoothing factor

        for t in range(1, T):
            smooth[:, t, :] = jitter_smooth * smooth[:, t-1, :] + alpha * noise[:, t, :]

        # add jitter
        seq_aug += smooth

    return seq_aug

# %%
def run_epoch(loader, model, criterion, optimizer=None):
    if optimizer is None:
        model.eval()
    else:
        model.train()

    total_loss = 0.0
    correct = 0
    total = 0

    for x_batch, y_batch in loader:    
        if optimizer is not None:
            # Training mode
            optimizer.zero_grad()

            '''
            # Apply augmentation per sample in the batch
            x_batch_aug = []
            for i in range(x_batch.shape[0]):
                x_aug = augment_skeleton_sequence(x_batch[i])
                x_batch_aug.append(x_aug)
            x_batch = torch.stack(x_batch_aug)
            '''

        x_batch = x_batch.to(device, dtype=torch.float32)
        y_batch = y_batch.to(device)
    
        logits = model(x_batch)
        loss = criterion(logits, y_batch)
    
        if optimizer is not None:
            loss.backward()
            optimizer.step()
    
        total_loss += loss.item() * x_batch.size(0)
    
        preds = logits.argmax(dim=1)
        correct += (preds == y_batch).sum().item()
        total += y_batch.size(0)
    
    avg_loss = total_loss / total
    acc = correct / total
    return avg_loss, acc


def train_model(train_loader, test_loader, model, epochs=10):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

    train_accs = []
    test_accs = []
    
    for epoch in tqdm(range(1, epochs + 1), desc="Epochs"):
        train_loss, train_acc = run_epoch(train_loader, model, criterion, optimizer)
        test_loss, test_acc = run_epoch(test_loader, model, criterion, optimizer=None)
        train_accs.append(train_acc)
        test_accs.append(test_acc)
    
        print(
            f"Epoch {epoch:02d} | "
            f"train_loss={train_loss:.4f}, train_acc={train_acc:.3f} | "
            f"test_loss={test_loss:.4f}, test_acc={test_acc:.3f}"
        )

    return train_accs, test_accs

model = MediapipeHandGestureCNN(num_classes=14).to(device)

epochs = 30
train_accs, test_accs = train_model(train_loader, test_loader, model, epochs=30)
# Out:
# Epochs:   3%|██████▌                                                                                                                                                                                            | 1/30 [00:10<05:17, 10.95s/it]
# Epoch 01 | train_loss=2.0123, train_acc=0.345 | test_loss=1.8917, test_acc=0.344
# Epochs:   7%|█████████████                                                                                                                                                                                      | 2/30 [00:21<05:06, 10.95s/it]
# Epoch 02 | train_loss=1.7714, train_acc=0.386 | test_loss=1.7494, test_acc=0.403
# Epochs:  10%|███████████████████▌                                                                                                                                                                               | 3/30 [00:32<04:55, 10.95s/it]
# Epoch 03 | train_loss=1.6142, train_acc=0.427 | test_loss=1.5494, test_acc=0.448
# Epochs:  13%|██████████████████████████                                                                                                                                                                         | 4/30 [00:43<04:44, 10.95s/it]
# Epoch 04 | train_loss=1.5081, train_acc=0.460 | test_loss=1.8206, test_acc=0.420
# Epochs:  17%|████████████████████████████████▌                                                                                                                                                                  | 5/30 [00:54<04:34, 10.97s/it]
# Epoch 05 | train_loss=1.3970, train_acc=0.493 | test_loss=1.3716, test_acc=0.522
# Epochs:  20%|███████████████████████████████████████                                                                                                                                                            | 6/30 [01:05<04:23, 10.96s/it]
# Epoch 06 | train_loss=1.2883, train_acc=0.519 | test_loss=1.4023, test_acc=0.546
# Epochs:  23%|█████████████████████████████████████████████▌                                                                                                                                                     | 7/30 [01:16<04:12, 10.97s/it]
# Epoch 07 | train_loss=1.1800, train_acc=0.561 | test_loss=1.1442, test_acc=0.627
# Epochs:  27%|████████████████████████████████████████████████████                                                                                                                                               | 8/30 [01:27<04:01, 10.97s/it]
# Epoch 08 | train_loss=1.0992, train_acc=0.618 | test_loss=0.9937, test_acc=0.743
# Epochs:  30%|██████████████████████████████████████████████████████████▌                                                                                                                                        | 9/30 [01:38<03:50, 10.97s/it]
# Epoch 09 | train_loss=0.9802, train_acc=0.649 | test_loss=1.0912, test_acc=0.724
# Epochs:  33%|████████████████████████████████████████████████████████████████▋                                                                                                                                 | 10/30 [01:49<03:39, 10.97s/it]
# Epoch 10 | train_loss=0.8936, train_acc=0.701 | test_loss=0.8802, test_acc=0.745
# Epochs:  37%|███████████████████████████████████████████████████████████████████████▏                                                                                                                          | 11/30 [02:00<03:28, 10.97s/it]
# Epoch 11 | train_loss=0.8059, train_acc=0.736 | test_loss=0.9871, test_acc=0.724
# Epochs:  40%|█████████████████████████████████████████████████████████████████████████████▌                                                                                                                    | 12/30 [02:11<03:17, 10.98s/it]
# Epoch 12 | train_loss=0.7199, train_acc=0.757 | test_loss=0.9066, test_acc=0.737
# Epochs:  43%|████████████████████████████████████████████████████████████████████████████████████                                                                                                              | 13/30 [02:22<03:06, 10.97s/it]
# Epoch 13 | train_loss=0.6770, train_acc=0.767 | test_loss=0.6881, test_acc=0.817
# Epochs:  47%|██████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                       | 14/30 [02:33<02:55, 10.99s/it]
# Epoch 14 | train_loss=0.6224, train_acc=0.786 | test_loss=0.7884, test_acc=0.813
# Epochs:  50%|█████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                 | 15/30 [02:44<02:44, 10.99s/it]
# Epoch 15 | train_loss=0.5788, train_acc=0.805 | test_loss=0.6332, test_acc=0.818
# Epochs:  53%|███████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                          | 16/30 [02:55<02:33, 10.99s/it]
# Epoch 16 | train_loss=0.5744, train_acc=0.807 | test_loss=0.6636, test_acc=0.830
# Epochs:  57%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                    | 17/30 [03:06<02:22, 10.98s/it]
# Epoch 17 | train_loss=0.5108, train_acc=0.815 | test_loss=0.6135, test_acc=0.853
# Epochs:  60%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                             | 18/30 [03:17<02:11, 10.98s/it]
# Epoch 18 | train_loss=0.5039, train_acc=0.816 | test_loss=0.6560, test_acc=0.832
# Epochs:  63%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                       | 19/30 [03:28<02:00, 10.98s/it]
# Epoch 19 | train_loss=0.4688, train_acc=0.839 | test_loss=0.5210, test_acc=0.864
# Epochs:  67%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                | 20/30 [03:39<01:49, 10.99s/it]
# Epoch 20 | train_loss=0.4488, train_acc=0.837 | test_loss=0.6128, test_acc=0.857
# Epochs:  70%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                          | 21/30 [03:50<01:38, 10.99s/it]
# Epoch 21 | train_loss=0.4178, train_acc=0.850 | test_loss=0.7299, test_acc=0.807
# Epochs:  73%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                   | 22/30 [04:01<01:27, 10.99s/it]
# Epoch 22 | train_loss=0.4003, train_acc=0.858 | test_loss=0.7357, test_acc=0.839
# Epochs:  77%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                             | 23/30 [04:12<01:16, 10.99s/it]
# Epoch 23 | train_loss=0.3973, train_acc=0.857 | test_loss=0.5205, test_acc=0.862
# Epochs:  80%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                      | 24/30 [04:23<01:05, 10.98s/it]
# Epoch 24 | train_loss=0.3896, train_acc=0.859 | test_loss=0.6046, test_acc=0.877
# Epochs:  83%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                | 25/30 [04:34<00:54, 10.98s/it]
# Epoch 25 | train_loss=0.3829, train_acc=0.865 | test_loss=0.5697, test_acc=0.873
# Epochs:  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                         | 26/30 [04:45<00:43, 10.99s/it]
# Epoch 26 | train_loss=0.3493, train_acc=0.875 | test_loss=0.6211, test_acc=0.872
# Epochs:  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                   | 27/30 [04:56<00:32, 10.99s/it]
# Epoch 27 | train_loss=0.3677, train_acc=0.872 | test_loss=0.6765, test_acc=0.859
# Epochs:  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████             | 28/30 [05:07<00:21, 10.99s/it]
# Epoch 28 | train_loss=0.3661, train_acc=0.863 | test_loss=0.7180, test_acc=0.843
# Epochs:  97%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌      | 29/30 [05:18<00:10, 11.00s/it]
# Epoch 29 | train_loss=0.3806, train_acc=0.870 | test_loss=0.7069, test_acc=0.851
# Epochs: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [05:29<00:00, 10.98s/it]
# Epoch 30 | train_loss=0.3546, train_acc=0.873 | test_loss=0.7565, test_acc=0.825

# %%
x = np.arange(epochs)
plt.figure(figsize=(8, 5))
plt.plot(x, train_accs, label='Train Accuracy')
plt.plot(x, test_accs, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy for CNN Model')
plt.legend()
plt.grid(True)
plt.show()
